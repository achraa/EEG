# %% [markdown]
# # Klasifikasi Stress EEG dengan Seleksi Channel

# %%
import os
import mne
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import keras_tuner as kt
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras  

import variables as v
import dataset
import features
import classifiers
import g_algrthm as ga

# %%
PATH_FILE_LOCS = v.CHANNELS_PATH
PATH_FILE_LABEL = v.LABELS_PATH

# %%
# Memuat data mentah dari semua 32 channel
full_dataset = dataset.load_dataset(data_type="raw", test_type="Arithmetic")
# Memuat daftar nama dari 32 channel tersebut dari file .locs
all_channels_list = dataset.load_channels()
print(f"Berhasil memuat dataset dengan {full_dataset.shape[1]} channel.")
print(f"Bentuk data: {full_dataset.shape}")
print(f"Daftar channel yang dimuat: {all_channels_list}")
# Out:
# Berhasil memuat dataset dengan 32 channel.
# Bentuk data: (120, 32, 3200)
# Daftar channel yang dimuat: ['Cz', 'Fz', 'Fp1', 'F7', 'F3', 'FC1', 'C3', 'FC5', 'FT9', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'PO9', 'O1', 'Pz', 'Oz', 'O2', 'PO10', 'P8', 'P4', 'CP2', 'CP6', 'T8', 'FT10', 'FC6', 'C4', 'FC2', 'F4', 'F8', 'Fp2']

# %% [markdown]
# ## Channel Selection

# %%
ga_parameters = {
    "num_generations": 10,
    "num_parents_mating": 5,
    "num_people_in_pop": 15,
    "num_channels_to_select": 8
}

raw_labels_df = dataset.load_labels()
num_epochs_per_trial = 12
labels_for_ga = dataset.format_labels(
    raw_labels_df, test_type="Arithmetic", epochs=num_epochs_per_trial)

selected_channels = ga.run_channel_selection(
    full_dataset=full_dataset,
    all_channels_list=all_channels_list,
    labels_for_ga=labels_for_ga,
    ga_params=ga_parameters
)
# Out:
#   -> Generasi 1/10...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 13
#       9 num_epochs_per_trial = 12
#      10 labels_for_ga = dataset.format_labels(
#      11     raw_labels_df, test_type="Arithmetic", epochs=num_epochs_per_trial)
# ---> 13 selected_channels = ga.run_channel_selection(
#      14     full_dataset=full_dataset,
#      15     all_channels_list=all_channels_list,
#      16     labels_for_ga=labels_for_ga,
#      17     ga_params=ga_parameters
#      18 )
#
# File d:\COOLYEAH\TUGAS AKHIR\EEG\g_algrthm.py:118, in run_channel_selection(full_dataset, all_channels_list, labels_for_ga, ga_params)
#     115 for generation in range(num_generations):
#     116     print(f"  -> Generasi {generation + 1}/{num_generations}...")
# --> 118     curr_pop_fitness_scores = convert_pop_to_fitness(
#     119         full_dataset, all_channels_list, curr_pop, labels_for_ga, num_channels_to_select)
#     121     # Bobot [akurasi, sensitivitas, spesifisitas]
#     122     equation_inputs = [1.5, 1, 1]
#
# File d:\COOLYEAH\TUGAS AKHIR\EEG\g_algrthm.py:75, in convert_pop_to_fitness(all_data, all_channels, current_pop, label, n_genes)
#      68 subset_data = get_subset(
#      69     all_data, all_channels, individual_channels.tolist())
#      71 # Ubah ke format epoch
#      72 # epoched_data = convert_to_epochs(subset_data, n_genes, v.SFREQ)
#      73
#      74 # Ekstrak fitur
# ---> 75 features = hjorth_features(subset_data)
#      77 # Hitung performa dengan classifier cepat
#      78 performance = knn(features, label)
#
# File d:\COOLYEAH\TUGAS AKHIR\EEG\feature.py:67, in hjorth_features(data)
#      57 def hjorth_features(data):
#      58     '''
#      59     Computes the features Hjorth mobility (spectral) and Hjorth complexity (spectral) using the package mne_features.
#      60
#    (...)     65         ndarray: Computed features.
#      66     '''
# ---> 67     n_trials, n_secs, n_channels, sfreq = data.shape
#      68     features_per_channel = 2
#      70     features = np.empty([n_trials, n_secs, n_channels * features_per_channel])
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %%
Data = ga.get_subset(
    data=full_dataset,
    all_genes=all_channels_list,
    subset_genes=selected_channels
)

print(f"\nChannel yang terpilih: {selected_channels}")
print(f"Bentuk data setelah seleksi channel: {Data.shape}")
# Out:
# Channel yang terpilih: ['CP1', 'FC6', 'CP5', 'Fp1', 'T8', 'T7', 'FC2', 'F8']
# Bentuk data setelah seleksi channel: (120, 8, 3200)

# %%
n_trials, n_channels, n_samples_per_trial = Data.shape
visdata = Data.reshape(n_channels, n_trials * n_samples_per_trial)

ch_names = selected_channels
ch_types = ['eeg'] * n_channels
sfreq = v.SFREQ 

info = mne.create_info(ch_names=ch_names, sfreq=sfreq, ch_types=ch_types)

# objek MNE RawArray dari data NumPy dan Info
mne_object = mne.io.RawArray(visdata, info)

# Plot sinyal menggunakan fungsi bawaan MNE
#    'n_channels' -> berapa channel yang ditampilkan sekaligus
#    'duration' -> berapa detik data yang ditampilkan per layar
#    'scalings' -> mengatur skala plot agar sinyal terlihat jelas
mne_object.plot(n_channels=8, duration=10, scalings='auto')
# Out:
# Creating RawArray with float64 data, n_channels=8, n_times=384000
#     Range : 0 ... 383999 =      0.000 ...  2999.992 secs
# Ready.
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
all_types_to_load = v.TRIAL_TYPES + v.BASELINE_TYPE

mne_objects_dict = {}

for data_type in all_types_to_load:
    temp_full_dataset = dataset.load_dataset(
        data_type = 'raw', test_type=data_type)
    temp_channels_selection = ga.get_subset(
        data=temp_full_dataset,
        all_genes=all_channels_list,
        subset_genes=selected_channels
    )

    n_trials, n_channels, n_samples = temp_channels_selection.shape
    data_for_mne = temp_channels_selection.reshape(
        n_channels, n_trials * n_samples)
    
    info = mne.create_info(
        ch_names=selected_channels,
        sfreq=v.SFREQ,
        ch_types=['eeg'] * len(selected_channels)
        )
    
    mne_objects_dict[data_type] = mne.io.RawArray(data_for_mne, info)

print(f'{len(mne_objects_dict)} jenis data telah dimuat ke dalam dictionary mne_objects_dict.')
# Out:
# Creating RawArray with float64 data, n_channels=8, n_times=384000
#     Range : 0 ... 383999 =      0.000 ...  2999.992 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=384000
#     Range : 0 ... 383999 =      0.000 ...  2999.992 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=384000
#     Range : 0 ... 383999 =      0.000 ...  2999.992 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=384000
#     Range : 0 ... 383999 =      0.000 ...  2999.992 secs
# Ready.
# 4 jenis data telah dimuat ke dalam dictionary mne_objects_dict.

# %% [markdown]
# ## Decomposed Data & Differential Entropy

# %%
decomposed_data = features.decompose_to_bands(mne_objects_dict)

de_features = features.differential_entropy_features(decomposed_data)
if de_features:
    print(
        f"Task yang berhasil diekstrak fiturnya: {list(de_features.keys())}")
    first_key = list(de_features.keys())[0]
    print(
        f"Bentuk vektor fitur untuk '{first_key}': {de_features[first_key].shape}")
# Out:
# Task yang berhasil diekstrak fiturnya: ['Arithmetic', 'Mirror', 'Stroop']
# Bentuk vektor fitur untuk 'Arithmetic': (32,)

# %%
task_to_visualize = 'Arithmetic'

band_order = ['Theta', 'Alpha', 'Beta', 'Gamma']

print(
    f"Menampilkan visualisasi sinyal per band untuk task: {task_to_visualize}")

# Loop untuk setiap nama band
for band_name in band_order:
    print(f"\n--- Visualisasi untuk Band: {band_name} ---")

    # Mengakses objek MNE untuk task dan band yang spesifik
    mne_band_object = decomposed_data[task_to_visualize][band_name]

    mne_band_object.plot(n_channels=8, duration=1, scalings='auto')
# Out:
# Menampilkan visualisasi sinyal per band untuk task: Arithmetic
#
# --- Visualisasi untuk Band: Theta ---
# <MNEBrowseFigure size 800x800 with 4 Axes>
# --- Visualisasi untuk Band: Alpha ---
# <MNEBrowseFigure size 800x800 with 4 Axes>
# --- Visualisasi untuk Band: Beta ---
# <MNEBrowseFigure size 800x800 with 4 Axes>
# --- Visualisasi untuk Band: Gamma ---
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %% [markdown]
# ## 3D Cube

# %%
feature_maps_3d = features.create_3d_feature_maps(
    feature_vectors_dict=de_features,
    montage_path=v.CHANNELS_PATH,
    selected_channels_list=selected_channels
    )

for task_name, feature_map in feature_maps_3d.items():
    features.visualize_3d_feature_map(
        feature_map,
        montage_path=v.CHANNELS_PATH,
        title=f"Peta Fitur Differential Entropy (DE) untuk Task: {task_name}"
    )

# %% [markdown]
# ## Classification

# %% [markdown]
# ### CCN

# %%
# Menggabungkan semua data task menjadi satu untuk diproses
all_task_data_list = []
for task_name in ["Arithmetic", "Mirror", "Stroop"]:
    temp_full_dataset = dataset.load_dataset(
        data_type="raw", test_type=task_name)
    temp_data_terseleksi = ga.get_subset(
        data=temp_full_dataset,
        all_genes=all_channels_list,
        subset_genes=selected_channels
    )
    all_task_data_list.append(temp_data_terseleksi)

# Menggabungkan data dari 3 task menjadi satu array besar (360, 8, 3200)
X_raw_selected = np.concatenate(all_task_data_list, axis=0)

# Mengubah data mentah menjadi epoch. Asumsi 2 detik per epoch.
# 3200 sampel / (128 Hz * 2 detik) = 12.5 -> 12 epoch per trial
epoched_data = dataset.convert_to_epochs(
    X_raw_selected, n_genes=len(selected_channels), sfreq=v.SFREQ)
# Bentuk output: (360 * 12, 8, 256)

# Ekstrak fitur Hjorth dari setiap epoch
X_features = features.hjorth_features(epoched_data)
# Bentuk output: (4320, 24) -> 4320 sampel, 24 fitur (8 channel * 3 fitur Hjorth)
print(f"Ekstraksi fitur selesai. Bentuk X: {X_features.shape}")


labels_df = dataset.load_labels()
# Mendapatkan label untuk semua 3 task dan ulangi untuk setiap epoch
num_epochs = epoched_data.shape[0] // X_raw_selected.shape[0]  # -> 12
y_binary = []
for task_name in ["Arithmetic", "Mirror", "Stroop"]:
    labels_for_task = dataset.format_labels(
        labels_df, test_type=task_name, epochs=num_epochs)
    y_binary.append(labels_for_task)

y_binary = np.concatenate(y_binary, axis=0)

# Ubah ke one-hot encoding
y = to_categorical(y_binary, num_classes=2)
print(f"Persiapan label selesai. Bentuk y: {y.shape}")


X_train, X_test, y_train, y_test = train_test_split(
    X_features, y, test_size=0.3, random_state=42, stratify=y
)
print(f"Bentuk X_train: {X_train.shape}, Bentuk y_train: {y_train.shape}")



input_size = X_train.shape[1]  # -> 24
output_size = y_train.shape[1]  # -> 2

model_nn = classifiers.NN(
    input_size=input_size, output_size=output_size,
    num_layers=3, num_neurons=[64, 32, 16], dropout_rate=0.3
)
model_nn.compile(optimizer='adam',
                 loss='categorical_crossentropy', metrics=['accuracy'])

print("\nMemulai pelatihan model NN...")
history = model_nn.fit(
    X_train, y_train,
    epochs=50, batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)

print("\n--- Mengevaluasi Performa Model ---")
loss, accuracy = model_nn.evaluate(X_test, y_test, verbose=0)
print(f"Akurasi final pada data test: {accuracy:.2%}")
# Out:
# Ekstraksi fitur selesai. Bentuk X: (4320, 24)
# Persiapan label selesai. Bentuk y: (4320, 2)
# Bentuk X_train: (3456, 24), Bentuk y_train: (3456, 2)
#
# Memulai pelatihan model NN...
# Epoch 1/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5140 - loss: 22.8146 - val_accuracy: 0.6400 - val_loss: 11.0744
# Epoch 2/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5166 - loss: 7.0348 - val_accuracy: 0.4664 - val_loss: 5.0679
# Epoch 3/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5922 - loss: 3.2459 - val_accuracy: 0.6319 - val_loss: 3.0713
# Epoch 4/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5854 - loss: 3.6267 - val_accuracy: 0.6123 - val_loss: 2.5867
# Epoch 5/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5919 - loss: 2.5565 - val_accuracy: 0.6181 - val_loss: 2.7985
# Epoch 6/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6135 - loss: 1.6807 - val_accuracy: 0.5741 - val_loss: 2.1390
# Epoch 7/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5855 - loss: 2.3440 - val_accuracy: 0.5208 - val_loss: 2.4388
# Epoch 8/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5752 - loss: 1.8541 - val_accuracy: 0.5995 - val_loss: 1.4155
# Epoch 9/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6052 - loss: 1.8120 - val_accuracy: 0.6100 - val_loss: 2.1395
# Epoch 10/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5976 - loss: 1.4521 - val_accuracy: 0.5127 - val_loss: 4.7328
# Epoch 11/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5473 - loss: 3.4747 - val_accuracy: 0.5938 - val_loss: 2.1777
# Epoch 12/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5901 - loss: 1.7807 - val_accuracy: 0.3634 - val_loss: 6.5129
# Epoch 13/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5484 - loss: 2.7726 - val_accuracy: 0.5926 - val_loss: 1.8232
# Epoch 14/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6192 - loss: 1.2342 - val_accuracy: 0.5417 - val_loss: 1.5408
# Epoch 15/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5952 - loss: 1.4457 - val_accuracy: 0.6458 - val_loss: 1.1482
# Epoch 16/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6350 - loss: 1.3208 - val_accuracy: 0.6157 - val_loss: 1.0937
# Epoch 17/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6152 - loss: 1.2575 - val_accuracy: 0.6227 - val_loss: 1.3218
# Epoch 18/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6179 - loss: 1.4795 - val_accuracy: 0.6366 - val_loss: 1.1007
# Epoch 19/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6259 - loss: 1.1265 - val_accuracy: 0.6100 - val_loss: 1.1229
# Epoch 20/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6225 - loss: 0.9129 - val_accuracy: 0.6262 - val_loss: 1.0377
# Epoch 21/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6229 - loss: 0.8351 - val_accuracy: 0.6111 - val_loss: 1.0826
# Epoch 22/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6372 - loss: 1.0098 - val_accuracy: 0.6481 - val_loss: 1.0058
# Epoch 23/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6305 - loss: 0.8239 - val_accuracy: 0.5856 - val_loss: 1.1628
# Epoch 24/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5992 - loss: 1.0805 - val_accuracy: 0.6331 - val_loss: 1.0422
# Epoch 25/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6568 - loss: 0.7838 - val_accuracy: 0.6424 - val_loss: 1.2283
# Epoch 26/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6502 - loss: 0.8549 - val_accuracy: 0.6424 - val_loss: 0.9908
# Epoch 27/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6376 - loss: 0.8169 - val_accuracy: 0.6273 - val_loss: 0.9475
# Epoch 28/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6443 - loss: 0.8226 - val_accuracy: 0.6470 - val_loss: 1.4375
# Epoch 29/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6419 - loss: 0.7763 - val_accuracy: 0.6076 - val_loss: 1.0200
# Epoch 30/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6090 - loss: 1.3753 - val_accuracy: 0.6470 - val_loss: 0.8010
# Epoch 31/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6315 - loss: 0.8069 - val_accuracy: 0.6076 - val_loss: 0.9428
# Epoch 32/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6232 - loss: 0.7833 - val_accuracy: 0.6435 - val_loss: 0.7082
# Epoch 33/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6438 - loss: 0.6966 - val_accuracy: 0.6435 - val_loss: 0.7005
# Epoch 34/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6443 - loss: 0.7851 - val_accuracy: 0.6424 - val_loss: 0.7412
# Epoch 35/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6364 - loss: 0.7599 - val_accuracy: 0.6447 - val_loss: 0.7792
# Epoch 36/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6491 - loss: 0.6809 - val_accuracy: 0.5764 - val_loss: 1.0643
# Epoch 37/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6490 - loss: 0.7406 - val_accuracy: 0.6424 - val_loss: 0.6767
# Epoch 38/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6466 - loss: 0.6514 - val_accuracy: 0.6481 - val_loss: 0.7952
# Epoch 39/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6603 - loss: 0.6939 - val_accuracy: 0.6505 - val_loss: 0.6526
# Epoch 40/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6477 - loss: 0.6573 - val_accuracy: 0.6528 - val_loss: 0.6646
# Epoch 41/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6397 - loss: 0.6538 - val_accuracy: 0.6435 - val_loss: 0.6861
# Epoch 42/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6459 - loss: 0.6720 - val_accuracy: 0.6458 - val_loss: 0.6659
# Epoch 43/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6388 - loss: 0.6797 - val_accuracy: 0.6424 - val_loss: 0.6710
# Epoch 44/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6431 - loss: 0.6416 - val_accuracy: 0.6458 - val_loss: 0.7372
# Epoch 45/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6277 - loss: 0.7272 - val_accuracy: 0.6424 - val_loss: 0.6667
# Epoch 46/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6347 - loss: 0.6950 - val_accuracy: 0.6435 - val_loss: 0.7663
# Epoch 47/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6674 - loss: 0.7001 - val_accuracy: 0.6377 - val_loss: 0.7149
# Epoch 48/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6544 - loss: 0.6650 - val_accuracy: 0.6435 - val_loss: 0.6673
# Epoch 49/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6453 - loss: 0.7127 - val_accuracy: 0.6435 - val_loss: 0.6862
# Epoch 50/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6469 - loss: 0.6544 - val_accuracy: 0.6424 - val_loss: 0.7265
#
# --- Mengevaluasi Performa Model ---
# Akurasi final pada data test: 64.24%

# %%
import metrics

y_pred_prob = model_nn.predict(X_test)
y_pred_classes = np.argmax(y_pred_prob, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)
metrics.plot_conf_matrix_and_stats(conf_matrix, class_names=[
                                   'Non-Stressed', 'Stressed'])
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Laporan Klasifikasi Rinci:
#               precision    recall  f1-score   support
#
# Non-Stressed       0.65      0.96      0.78       559
#     Stressed       0.46      0.07      0.12       305
#
#     accuracy                           0.64       864
#    macro avg       0.55      0.51      0.45       864
# weighted avg       0.58      0.64      0.54       864
